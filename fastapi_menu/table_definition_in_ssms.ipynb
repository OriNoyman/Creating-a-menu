-- %% [markdown]
-- # [dbo].[Menu]

-- %%
USE [TableDefinition]
GO

-- %%
/****** Object:  Table [dbo].[Menu]    Script Date: 13/10/2024 03:01:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Menu](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [varchar](max) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[menu_action_link]

-- %%
/****** Object:  Table [dbo].[menu_action_link]    Script Date: 13/10/2024 03:01:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[menu_action_link](
	[menu_id] [int] NULL,
	[menu_action_id] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MenuAction]

-- %%
/****** Object:  Table [dbo].[MenuAction]    Script Date: 13/10/2024 03:01:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MenuAction](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[action_name] [varchar](255) NOT NULL,
	[description] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[action_name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MenuItem]

-- %%
/****** Object:  Table [dbo].[MenuItem]    Script Date: 13/10/2024 03:01:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MenuItem](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [varchar](max) NOT NULL,
	[menu_id] [int] NULL,
	[action_route] [varchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MenuOption]

-- %%
/****** Object:  Table [dbo].[MenuOption]    Script Date: 13/10/2024 03:01:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MenuOption](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[menu_id] [int] NULL,
	[action_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[User]

-- %%
/****** Object:  Table [dbo].[User]    Script Date: 13/10/2024 03:01:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[User](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[username] [varchar](255) NOT NULL,
	[password] [varchar](255) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[username] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[user_menu]

-- %%
/****** Object:  Table [dbo].[user_menu]    Script Date: 13/10/2024 03:01:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[user_menu](
	[user_id] [int] NULL,
	[menu_id] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__menu_acti__menu___4E88ABD4]

-- %%
ALTER TABLE [dbo].[menu_action_link]  WITH CHECK ADD FOREIGN KEY([menu_id])
REFERENCES [dbo].[Menu] ([id])
GO

-- %% [markdown]
-- # [FK__menu_acti__menu___4F7CD00D]

-- %%
ALTER TABLE [dbo].[menu_action_link]  WITH CHECK ADD FOREIGN KEY([menu_action_id])
REFERENCES [dbo].[MenuAction] ([id])
GO

-- %% [markdown]
-- # [FK__MenuItem__menu_i__45F365D3]

-- %%
ALTER TABLE [dbo].[MenuItem]  WITH CHECK ADD FOREIGN KEY([menu_id])
REFERENCES [dbo].[Menu] ([id])
GO

-- %% [markdown]
-- # [FK__MenuOptio__actio__49C3F6B7]

-- %%
ALTER TABLE [dbo].[MenuOption]  WITH CHECK ADD FOREIGN KEY([action_id])
REFERENCES [dbo].[MenuAction] ([id])
GO

-- %% [markdown]
-- # [FK__MenuOptio__menu___48CFD27E]

-- %%
ALTER TABLE [dbo].[MenuOption]  WITH CHECK ADD FOREIGN KEY([menu_id])
REFERENCES [dbo].[Menu] ([id])
GO

-- %% [markdown]
-- # [FK__user_menu__menu___4CA06362]

-- %%
ALTER TABLE [dbo].[user_menu]  WITH CHECK ADD FOREIGN KEY([menu_id])
REFERENCES [dbo].[Menu] ([id])
GO

-- %% [markdown]
-- # [FK__user_menu__user___4BAC3F29]

-- %%
ALTER TABLE [dbo].[user_menu]  WITH CHECK ADD FOREIGN KEY([user_id])
REFERENCES [dbo].[User] ([id])
GO
